# %% [markdown]
# # Introduction

# %% [markdown]
# <center><img src="https://i.imgur.com/9hLRsjZ.jpg" height=400></center>
#
# This dataset was scraped from [nextspaceflight.com](https://nextspaceflight.com/launches/past/?page=1) and includes all the space missions since the beginning of Space Race between the USA and the Soviet Union in 1957!

# %% [markdown]
# ### Install Package with Country Codes

# %%
# %pip install iso3166
# Out:
# Collecting iso3166
#   Downloading iso3166-2.1.1-py3-none-any.whl.metadata (6.6 kB)
# Downloading iso3166-2.1.1-py3-none-any.whl (9.8 kB)
# Installing collected packages: iso3166
# Successfully installed iso3166-2.1.1

# %% [markdown]
# ### Upgrade Plotly
#
# Run the cell below if you are working with Google Colab.

# %%
# %pip install --upgrade plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Collecting plotly
#   Downloading plotly-6.5.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)
# Downloading plotly-6.5.2-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 68.1 MB/s eta 0:00:00
# Installing collected packages: plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# Successfully installed plotly-6.5.2

# %% [markdown]
# ### Import Statements

# %%
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# These might be helpful:
from iso3166 import countries
from datetime import datetime, timedelta

# %% [markdown]
# ### Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### Load the Data

# %%
df_data = pd.read_csv('mission_launches.csv')

# %% [markdown]
# # Preliminary Data Exploration
#
# * What is the shape of `df_data`?
# * How many rows and columns does it have?
# * What are the column names?
# * Are there any NaN values or duplicates?

# %%
df_data.shape
# Out:
# (4324, 9)

# %%
df_data['Date'] = pd.to_datetime(df_data['Date'], utc=True, errors='coerce').dt.tz_localize(None)

# %%
df_data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Organisation  \
# 0             0           0       SpaceX
# 1             1           1         CASC
# 2             2           2       SpaceX
# 3             3           3    Roscosmos
# 4             4           4          ULA
#
#                                             Location                Date  \
# 0         LC-39A, Kennedy Space Center, Florida, USA 2020-08-07 05:12:00
# 1  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce... 2020-08-06 04:01:00
# 2                      Pad A, Boca Chica, Texas, USA 2020-08-04 23:57:00
# 3       Site 200/39, Baikonur Cosmodrome, Kazakhstan 2020-07-30 21:25:00
# 4           SLC-41, Cape Canaveral AFS, Florida, USA 2020-07-30 11:50:00
#
#                                          Detail Rocket_Status  Price  \
# 0  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky  StatusActive  50.00
# 1           Long March 2D | Gaofen-9 04 & Q-SAT  StatusActive  29.75
# 2            Starship Prototype | 150 Meter Hop  StatusActive    NaN
# 3  Proton-M/Briz-M | Ekspress-80 & Ekspress-103  StatusActive  65.00
# 4                    Atlas V 541 | Perseverance  StatusActive 145.00
#
#   Mission_Status
# 0        Success
# 1        Success
# 2        Success
# 3        Success
# 4        Success

# %% [markdown]
# ## Data Cleaning - Check for Missing Values and Duplicates
#
# Consider removing columns containing junk data.

# %%
df_data.isnull().any()
# Out:
# Unnamed: 0.1      False
# Unnamed: 0        False
# Organisation      False
# Location          False
# Date               True
# Detail            False
# Rocket_Status     False
# Price              True
# Mission_Status    False
# dtype: bool

# %%
df_data['Price'] = df_data['Price'].fillna(0)

# %%
df_data.isnull().any()
# Out:
# Unnamed: 0.1      False
# Unnamed: 0        False
# Organisation      False
# Location          False
# Date               True
# Detail            False
# Rocket_Status     False
# Price             False
# Mission_Status    False
# dtype: bool

# %% [markdown]
# ## Descriptive Statistics

# %%
df_data.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0                           Date    Price
# count      4,324.00    4,324.00                           4198 4,324.00
# mean       2,161.50    2,161.50  1987-12-23 12:59:23.639828416    34.29
# min            0.00        0.00            1957-10-04 19:28:00     0.00
# 25%        1,080.75    1,080.75            1972-05-05 17:21:00     0.00
# 50%        2,161.50    2,161.50            1985-01-24 06:21:30     0.00
# 75%        3,242.25    3,242.25            2002-10-05 00:25:30     0.00
# max        4,323.00    4,323.00            2020-08-07 05:12:00 5,000.00
# std        1,248.38    1,248.38                            NaN   150.44

# %%
df_data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Organisation', 'Location', 'Date',
#        'Detail', 'Rocket_Status', 'Price', 'Mission_Status'],
#       dtype='object')

# %%
df_data = df_data.drop('Unnamed: 0.1', axis=1)

# %%
df_data = df_data.drop('Unnamed: 0', axis=1)

# %%
df_data.head(1)
# Out:
#   Organisation                                    Location  \
# 0       SpaceX  LC-39A, Kennedy Space Center, Florida, USA
#
#                  Date                                        Detail  \
# 0 2020-08-07 05:12:00  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
#
#   Rocket_Status  Price Mission_Status
# 0  StatusActive  50.00        Success

# %% [markdown]
# # Number of Launches per Company
#
# Create a chart that shows the number of space mission launches by organisation.

# %%
df_data['Organisation'].count()
# Out:
# np.int64(4324)

# %%
launch_count = df_data['Organisation'].value_counts()

bar = px.bar(x = launch_count.index, y = launch_count.values, title='Number of Launch Per organisation')

bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="465b383b-f6ab-4404-876a-8ae6d3485e25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("465b383b-f6ab-4404-876a-8ae6d3485e25")) {                    Plotly.newPlot(                        "465b383b-f6ab-4404-876a-8ae6d3485e25",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["RVSN USSR","Arianespace","General Dynamics","CASC","NASA","VKS RF","US Air Force","ULA","Boeing","Martin Marietta","SpaceX","MHI","Northrop","Lockheed","ISRO","Roscosmos","ILS","Sea Launch","ISAS","Kosmotras","US Navy","Rocket Lab","ISA","Eurockot","ESA","Blue Origin","IAI","ExPace","ASI","CNES","AMBA","JAXA","Land Launch","MITT","UT","CASIC","KCST","Exos","CECLES","Arm??e de l'Air","SRC","KARI","AEB","RAE","Yuzhmash","OKB-586","Virgin Orbit","IRGC","OneSpace","Landspace","i-Space","Sandia","Starsem","Khrunichev","Douglas","EER"],"xaxis":"x","y":{"dtype":"i2","bdata":"8QYXAfsA+wDLAMkAoQCMAIgAcgBkAFQAUwBPAEwANwAuACQAHgAWABEADQANAA0ADQAMAAsACgAJAAgACAAHAAcABwAFAAUABQAEAAQABAADAAMAAwACAAIAAgABAAEAAQABAAEAAQABAAEAAQABAA=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{" ...

# %% [markdown]
# # Number of Active versus Retired Rockets
#
# How many rockets are active compared to those that are decomissioned?

# %%
df_data.head(1)
# Out:
#   Organisation                                    Location  \
# 0       SpaceX  LC-39A, Kennedy Space Center, Florida, USA
#
#                  Date                                        Detail  \
# 0 2020-08-07 05:12:00  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
#
#   Rocket_Status  Price Mission_Status
# 0  StatusActive  50.00        Success

# %%
df_data['Rocket_Status'].value_counts()
# Out:
# Rocket_Status
# StatusRetired    3534
# StatusActive      790
# Name: count, dtype: int64

# %% [markdown]
# # Distribution of Mission Status
#
# How many missions were successful?
# How many missions failed?

# %%
df_data['Mission_Status'].value_counts()
# Out:
# Mission_Status
# Success              3879
# Failure               339
# Partial Failure       102
# Prelaunch Failure       4
# Name: count, dtype: int64

# %% [markdown]
# # How Expensive are the Launches?
#
# Create a histogram and visualise the distribution. The price column is given in USD millions (careful of missing values).

# %%
df_data['Date'] = pd.to_datetime(df_data['Date'], format='mixed')

# %%
df_data['Date'].head()
# Out:
# 0   2020-08-07 05:12:00
# 1   2020-08-06 04:01:00
# 2   2020-08-04 23:57:00
# 3   2020-07-30 21:25:00
# 4   2020-07-30 11:50:00
# Name: Date, dtype: datetime64[ns]

# %%
fig = px.histogram(df_data, x='Date', y='Price')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="57eaee63-1bc7-4d65-bd85-af280adffba8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("57eaee63-1bc7-4d65-bd85-af280adffba8")) {                    Plotly.newPlot(                        "57eaee63-1bc7-4d65-bd85-af280adffba8",                        [{"bingroup":"x","histfunc":"sum","hovertemplate":"Date=%{x}\u003cbr\u003esum of Price=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"x":["2020-08-07T05:12:00","2020-08-06T04:01:00","2020-08-04T23:57:00","2020-07-30T21:25:00","2020-07-30T11:50:00","2020-07-25T03:13:00","2020-07-23T14:26:00","2020-07-23T04:41:00","2020-07-20T21:30:00","2020-07-19T21:58:00","2020-07-15T13:46:00","2020-07-10T04:17:00","2020-07-09T12:11:00","2020-07-06T01:00:00","2020-07-04T23:44:00","2020-07-04T21:19:00","2020-07-03T03:10:00","2020-06-30T20:10:00","2020-06-23T01:43:00","2020-06-17T07:19:00","2020-06-13T09:21:00","2020-06-13T05:12:00","2020-06-10T18:31:00","2020-06-04T01:25:00","2020-05-31T08:53:00","2020-05-30T19:22:00","2020-05-29T20:13:00","2020-05-25T19:50:00","2020-05-22T07:31:00","2020-05-20T17:31:00","2020-05-17T13:14:00","2020-05-12T01:16:00","2020-05-05T10:00:00","2020-04-25T01:51:00","2020-04-22T19:30:00","2020-04-22T03:59:00","2020-04-09T11:46:00","2020-04-09T08:05:00","2020-03-26T20:18:00","2020-03-24T03:43:00","2020-03-21T17:06:00","2020-03-18T12:16:00","2020-03-16T18:28:00","2020-03-16T13:34:00","2020-03-09T11:55:00","2020-03-07T04:50:00","2020-02-20T08:24:00","2020-02-19T21:07:00","2020-02-18T22:18:00","2020-02-17T15:05:00","2020-02-15T20:21:00","2020-02-10T04:03:00","2020-02-09T15:48:00","2020-02-09T01:34:00","2020-02-06T21:42:00","2020-01-31T02:56:00","2020-01-29T14:06:00","2020-01-19T15:30:00","2020-01-16T21:05:00","2020-01-16T03:02:00","2020-01-15T02:53:00","2020-01-07T15:20:00","2020-01-07T02:19:00","2019-12-27T12:45:00","2019-12-26T23:11:00","2019-12-24T12:03:00","2019-12-20T11:36:00","2019-12-20T03:22:00","2019-12-18T08:54:00","2019-12-17T00:10:00","2019-12-16T07:22:00","2019-12-11T17:55:00","2019-12-11T09:55:00","2019-12-11T08:54:00","2019-12-07T08:52:00","2019-12-07T02:55:00","2019-12-06T09:34:00","2019-12-06T08:18:00","2019-12-05T17:29:00","2019-11-27T23:52:00","2019-11-27T03:58:00","2019-11-26T21:23:00","2019-11-25T17:52:00","2019-11-23T00:55:00","2019-11-17T10:00:00","2019-11-13T06:35:00","2019-11-13T03:40:00","2019-11-11T14:56:00","2019-11-04T17:43:00","2019-11-03T03:22:00","2019-11-02T13:59:00","2019-10-26T17:40:00","2019-10-17T15:21:00","2019-10-17T01:22:00","2019-10-11T01:59:00","2019-10-09T10:17:00","2019-10-04T18:51:00","2019-09-26T07:46:00","2019-09-25T13:57:00","2019-09-25T00:54:00","2019-09-24T16:05:00","2019-09-22T21:10:00","2019-09-19T06:42:00","2019-09-12T03:26:00","2019-08-30T23:41:00","2019-08-30T14:00:00","1677-09-21T00:12:43.145224","2019-08-22T13:06:00","2019-08-22T03:38:00","2019-08-19T12:12:00","2019-08-19T12:03:00","2019-08-17T04:11:00","2019-08-08T10:13:00","2019-08-06T23:23:00","2019-08-06T19:30:00","2019-08-05T21:56:00","2019-07-31T12:10:00","2019-07-30T05:56:00","2019-07-26T03:57:00","2019-07-25T22:01:00","2019-07-25T05:00:00","2019-07-22T09:13:00","2019-07-20T16:28:00","2019-07-13T12:31:00","2019-07-11T01:53:00","2019-07-10T17:14:00","2019-07-05T05:41:00","2019-06-29T18:00:00","2019-06-29T04:30:00","2019-06-25T06:30:00","2019-06-24T18:09:00","2019-06-20T21:43:00","2019-06-12T14:17:00","2019-06-05T04:06:00","2019-05-30T17:42:00","2019-05-27T06:23:00","2019-05-24T02:30:00","2019-05-22T22:55:00","2019-05-22T00:00:00","2019-05-17T15:48:00","2019-05-05T06:00:00","2019-05-04 ...

# %% [markdown]
# # Use a Choropleth Map to Show the Number of Launches by Country
#
# * Create a choropleth map using [the plotly documentation](https://plotly.com/python/choropleth-maps/)
# * Experiment with [plotly's available colours](https://plotly.com/python/builtin-colorscales/). I quite like the sequential colour `matter` on this map.
# * You'll need to extract a `country` feature as well as change the country names that no longer exist.
#
# Wrangle the Country Names
#
# You'll need to use a 3 letter country code for each country. You might have to change some country names.
#
# * Russia is the Russian Federation
# * New Mexico should be USA
# * Yellow Sea refers to China
# * Shahrud Missile Test Site should be Iran
# * Pacific Missile Range Facility should be USA
# * Barents Sea should be Russian Federation
# * Gran Canaria should be USA
#
#
# You can use the iso3166 package to convert the country names to Alpha3 format.

# %%
def get_country_code(location):
    # Manual mapping for non-standard country names
    country_mapping = {
        'Russia': 'RUS',
        'South Korea': 'KOR',
        'North Korea': 'PRK',
        'New Mexico': 'USA',  # If you have US states
        'Iran': 'IRN',
        'Syria': 'SYR',
        'Venezuela': 'VEN',
        'Bolivia': 'BOL',
        'Tanzania': 'TZA',
        'Vietnam': 'VNM',
        'Laos': 'LAO'
    }

    try:
        country_name = location.split(',')[-1].strip()

        # Check manual mapping first
        if country_name in country_mapping:
            return country_mapping[country_name]

        # Otherwise use iso3166
        return countries.get(country_name).alpha3
    except (KeyError, AttributeError):
        return None

df_data['Alpha3Code'] = df_data['Location'].apply(get_country_code)

# %%
df_data['Alpha3Code'].unique()
# Out:
# array(['USA', 'CHN', 'KAZ', 'JPN', 'ISR', 'NZL', 'RUS', None, 'FRA',
#        'IRN', 'IND', 'PRK', 'KOR', 'BRA', 'KEN', 'AUS'], dtype=object)

# %%
launch_counts = df_data.groupby('Alpha3Code').size().reset_index(name='Number_of_Launches')

fig = px.choropleth(launch_counts, locations= 'Alpha3Code',
                    color='Number_of_Launches',
                    labels={'Number_of_Launches': 'Launches'},
                    title='Number of Launches Per country',
                    hover_name='Alpha3Code',
                    color_continuous_scale = 'matter')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="c73072df-7c26-4606-b606-78cbaaa6ddbf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c73072df-7c26-4606-b606-78cbaaa6ddbf")) {                    Plotly.newPlot(                        "c73072df-7c26-4606-b606-78cbaaa6ddbf",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eAlpha3Code=%{location}\u003cbr\u003eLaunches=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["AUS","BRA","CHN","FRA","IND","IRN","ISR","JPN","KAZ","KEN","KOR","NZL","PRK","RUS","USA"],"locations":["AUS","BRA","CHN","FRA","IND","IRN","ISR","JPN","KAZ","KEN","KOR","NZL","PRK","RUS","USA"],"name":"","z":{"dtype":"i2","bdata":"BgADAAwBLwFMAA0ACwB+AL0CCQADAA0ABQBzBUQF"},"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay", ...

# %%
df_data[df_data['Alpha3Code']== 'None']
# Out:
# Empty DataFrame
# Columns: [Organisation, Location, Date, Detail, Rocket_Status, Price, Mission_Status, Alpha3Code]
# Index: []

# %% [markdown]
# # Use a Choropleth Map to Show the Number of Failures by Country

# %%
failure_by_country = df_data[df_data['Mission_Status'] == 'Failure'].groupby('Alpha3Code').size().reset_index(name='Failures Per country')

# %%
failure_by_country.head(2)
# Out:
#   Alpha3Code  Failures Per country
# 0        AUS                     3
# 1        BRA                     2

# %%
fig = px.choropleth(failure_by_country,
                    locations='Alpha3Code',
                    title="Number of Failure per country",
                    hover_name='Alpha3Code',
                    color_continuous_scale='matter',
                    color="Failures Per country")


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="0da0b34c-badf-47d3-bcea-4f6fbd9da991" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0da0b34c-badf-47d3-bcea-4f6fbd9da991")) {                    Plotly.newPlot(                        "0da0b34c-badf-47d3-bcea-4f6fbd9da991",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eAlpha3Code=%{location}\u003cbr\u003eFailures Per country=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["AUS","BRA","CHN","FRA","IND","IRN","ISR","JPN","KAZ","KOR","NZL","PRK","RUS","USA"],"locations":["AUS","BRA","CHN","FRA","IND","IRN","ISR","JPN","KAZ","KOR","NZL","PRK","RUS","USA"],"name":"","z":{"dtype":"i2","bdata":"AwACABMADQAIAAgAAgAKAEgAAgACAAMAPgCAAA=="},"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay", ...

# %% [markdown]
# # Create a Plotly Sunburst Chart of the countries, organisations, and mission status.

# %%
mission_counts = df_data.groupby(['Alpha3Code', 'Organisation', 'Mission_Status']).size().reset_index(name='Count')

# %%
mission_counts = mission_counts.dropna(subset=['Alpha3Code', 'Organisation', 'Mission_Status'])

# %%
mission_counts.head(1)
# Out:
#   Alpha3Code Organisation Mission_Status  Count
# 0        AUS         AMBA        Success      1

# %%
fig = px.sunburst(
    mission_counts,
    path=['Alpha3Code','Organisation', 'Mission_Status'],
    values='Count',
    title="Mission Success/Failure per country, organisation"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="fd1094b0-2dff-4aff-9932-65686b76ba88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fd1094b0-2dff-4aff-9932-65686b76ba88")) {                    Plotly.newPlot(                        "fd1094b0-2dff-4aff-9932-65686b76ba88",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eCount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["AUS\u002fAMBA\u002fSuccess","AUS\u002fCECLES\u002fFailure","AUS\u002fCECLES\u002fSuccess","AUS\u002fRAE\u002fFailure","AUS\u002fRAE\u002fSuccess","BRA\u002fAEB\u002fFailure","BRA\u002fAEB\u002fPrelaunch Failure","CHN\u002fCASC\u002fFailure","CHN\u002fCASC\u002fPartial Failure","CHN\u002fCASC\u002fSuccess","CHN\u002fCASIC\u002fFailure","CHN\u002fCASIC\u002fSuccess","CHN\u002fExPace\u002fFailure","CHN\u002fExPace\u002fSuccess","CHN\u002fLandspace\u002fFailure","CHN\u002fOneSpace\u002fFailure","CHN\u002fi-Space\u002fSuccess","FRA\u002fArianespace\u002fFailure","FRA\u002fArianespace\u002fPartial Failure","FRA\u002fArianespace\u002fSuccess","FRA\u002fArm??e de l'Air\u002fPartial Failure","FRA\u002fArm??e de l'Air\u002fSuccess","FRA\u002fCECLES\u002fFailure","FRA\u002fCNES\u002fFailure","FRA\u002fCNES\u002fSuccess","FRA\u002fESA\u002fFailure","FRA\u002fESA\u002fPartial Failure","FRA\u002fESA\u002fSuccess","IND\u002fISRO\u002fFailure","IND\u002fISRO\u002fPartial Failure","IND\u002fISRO\u002fSuccess","IRN\u002fISA\u002fFailure","IRN\u002fISA\u002fPrelaunch Failure","IRN\u002fISA\u002fSuccess","ISR\u002fIAI\u002fFailure","ISR\u002fIAI\u002fSuccess","JPN\u002fISAS\u002fFailure","JPN\u002fISAS\u002fPartial Failure","JPN\u002fISAS\u002fSuccess","JPN\u002fJAXA\u002fFailure","JPN\u002fJAXA\u002fSuccess","JPN\u002fMHI\u002fFailure","JPN\u002fMHI\u002fPartial Failure","JPN\u002fMHI\u002fSuccess","JPN\u002fUT\u002fFailure","JPN\u002fUT\u002fSuccess","KAZ\u002fArianespace\u002fSuccess","KAZ\u002fILS\u002fPartial Failure","KAZ\u002fILS\u002fSuccess","KAZ\u002fKosmotras\u002fFailure","KAZ\u002fKosmotras\u002fSuccess","KAZ\u002fLand Launch\u002fPartial Failure","KAZ\u002fLand Launch\u002fSuccess","KAZ\u002fOKB-586\u002fSuccess","KAZ\u002fRVSN USSR\u002fFailure","KAZ\u002fRVSN USSR\u002fPartial Failure","KAZ\u002fRVSN USSR\u002fPrelaunch Failure","KAZ\u002fRVSN USSR\u002fSuccess","KAZ\u002fRoscosmos\u002fFailure","KAZ\u002fRoscosmos\u002fPartial Failure","KAZ\u002fRoscosmos\u002fSuccess","KAZ\u002fStarsem\u002fSuccess","KAZ\u002fVKS RF\u002fFailure","KAZ\u002fVKS RF\u002fSuccess","KAZ\u002fYuzhmash\u002fSuccess","KEN\u002fASI\u002fSuccess","KOR\u002fKARI\u002fFailure","KOR\u002fKARI\u002fSuccess","NZL\u002fRocket Lab\u002fFailure","NZL\u002fRocket Lab\u002fSuccess","PRK\u002fKCST\u002fFailure","PRK\u002fKCST\u002fSuccess","RUS\u002fEurockot\u002fFailure","RUS\u002fEurockot\u002fSuccess","RUS\u002fKhrunichev\u002fSuccess","RUS\u002fKosmotras\u002fSuccess","RUS\u002fMITT\u002fFailure","RUS\u002fMITT\u002fSuccess","RUS\u002fRVSN USSR\u002fFailure","RUS\u002fRVSN USSR\u002fPartial Failure","RUS\u002fRVSN USSR\u002fSuccess","RUS\u002fRoscosmos\u002fFailure","RUS\u002fRoscosmos\u002fSuccess","RUS\u002fVKS RF\u002fFailure","RUS\u002fVKS RF\u002fPartial Failure","RUS\u002fVKS RF\u002fSuccess","RUS\u002fYuzhmash\u002fSuccess","USA\u002fAMBA\u002fFailure","USA\u002fAMBA\u002fPartial Failure","USA\u002fAMBA\u002fSuccess","USA\u002fBlue Origin\u002fSuccess","USA\u002fBoeing\u002fFailure","USA\u002fBoeing\u002fPartial Failure","USA\u002fBoeing\u002fSuccess","USA\u002fDouglas\u002fSuccess","USA\u002fEER\u002fFailure","USA\u002 ...

# %% [markdown]
# # Analyse the Total Amount of Money Spent by Organisation on Space Missions

# %%
df_data['Price'] = df_data['Price'].str.replace(',','').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-162005651.py in <cell line: 0>()
# ----> 1 df_data['Price'] = df_data['Price'].str.replace(',','').astype(float)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     189         from pandas.core.arrays.string_ import StringDtype
#     190
# --> 191         self._inferred_dtype = self._validate(data)
#     192         self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     193         self._is_string = isinstance(data.dtype, StringDtype)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/strings/accessor.py in _validate(data)
#     243
#     244         if inferred_dtype not in allowed_types:
# --> 245             raise AttributeError("Can only use .str accessor with string values!")
#     246         return inferred_dtype
#     247
#
# AttributeError: Can only use .str accessor with string values!

# %%
total_money_spend = df_data.groupby('Organisation', as_index=False).agg({'Price': pd.Series.sum})

# %%
df_data["Price"].dtype

# %%
total_money_spend.head()

# %%
fig = px.bar(total_money_spend, x='Organisation', y='Price')
fig.show()

# %% [markdown]
# # Chart the Number of Launches per Year

# %%
# Convert to datetime first
df_data['Year'] = df_data['Date'].dt.year
launches_per_year = df_data.groupby('Year').size().reset_index(name='Launches')
launches_per_year['Cumulative_Launches'] = launches_per_year['Launches'].cumsum()

# %%
launches_per_year.head()

# %%
fig = px.line(launches_per_year, x='Year', y='Launches')

# %%
fig.show()

# %% [markdown]
# # Chart the Number of Launches Month-on-Month until the Present
#
# Which month has seen the highest number of launches in all time? Superimpose a rolling average on the month on month time series chart.

# %%
df_data['YearMonth' ] = df_data['Date'].dt.to_period('M').dt.to_timestamp()

# %%
launches_monthly = df_data.groupby('YearMonth').size().reset_index(name='Launches')

# %%
launches_monthly['Rolling Avg'] = launches_monthly['Launches'].rolling(window=12).mean()

# %%
launches_monthly.head()

# %%
fig = px.line(launches_monthly, x='YearMonth', y='Launches', title='Monthly Launches with rolling average')

# %%
fig.add_scatter(x=launches_monthly['YearMonth'], y=launches_monthly['Rolling Avg'],mode='lines', name='Rolling avg for 12 month', line=dict(color='red', width=2))

# %%
fig.update_layout(xaxis_title='Date', yaxis_title='Number of Launches')
fig.show()

# %% [markdown]
# # Launches per Month: Which months are most popular and least popular for launches?
#
# Some months have better weather than others. Which time of year seems to be best for space missions?

# %%
df_data.head()

# %%
df_data['Month'].value_counts()

# %% [markdown]
# # How has the Launch Price varied Over Time?
#
# Create a line chart that shows the average price of rocket launches over time.

# %%
avg_price = df_data.groupby(['Year', 'Price'],as_index=False).agg({'Price': pd.Series.mean})

avg_price.head()

# %%
fig = px.line(avg_price, x='Year', y='Price')

fig.show()

# %% [markdown]
# # Chart the Number of Launches over Time by the Top 10 Organisations.
#
# How has the dominance of launches changed over time between the different players?

# %%
top_10_org = df_data['Organisation'].value_counts().head(10).index

# %%
df_top10 = df_data[df_data['Organisation'].isin(top_10_org)]

# %%
df_top10.head()

# %%
launches_by_org = df_top10.groupby(['Year', 'Organisation']).size().reset_index(name='Launches')

# %%
launches_by_org.head()

# %%
fig = px.line(launches_by_org, x='Year', y='Launches', color='Organisation')

# %%
fig.update_layout(xaxis_title='Date', yaxis_title='Number of Launches')

fig.show()

# %% [markdown]
# ## Create a Plotly Pie Chart comparing the total number of launches of the USSR and the USA
#
# Hint: Remember to include former Soviet Republics like Kazakhstan when analysing the total number of launches.

# %%
df_data['Alpha3Code'].unique()
# Out:
# array(['USA', 'CHN', 'KAZ', 'JPN', 'ISR', 'NZL', 'RUS', None, 'FRA',
#        'IRN', 'IND', 'PRK', 'KOR', 'BRA', 'KEN', 'AUS'], dtype=object)

# %%
former_ussr = ['RUS', 'KAZ', 'UKR', 'BLR', 'UZB', 'AZE', 'GEO',
               'TJK', 'KGZ', 'TKM', 'ARM', 'LTU', 'LVA', 'EST', 'MDA']

df_data['is_former_USSR'] = df_data['Alpha3Code'].isin(former_ussr)

# %%
df_data.head()
# Out:
#   Organisation                                           Location  \
# 0       SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1         CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2       SpaceX                      Pad A, Boca Chica, Texas, USA
# 3    Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4          ULA           SLC-41, Cape Canaveral AFS, Florida, USA
#
#                  Date                                        Detail  \
# 0 2020-08-07 05:12:00  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
# 1 2020-08-06 04:01:00           Long March 2D | Gaofen-9 04 & Q-SAT
# 2 2020-08-04 23:57:00            Starship Prototype | 150 Meter Hop
# 3 2020-07-30 21:25:00  Proton-M/Briz-M | Ekspress-80 & Ekspress-103
# 4 2020-07-30 11:50:00                    Atlas V 541 | Perseverance
#
#   Rocket_Status  Price Mission_Status Alpha3Code  is_former_USSR
# 0  StatusActive  50.00        Success        USA           False
# 1  StatusActive  29.75        Success        CHN           False
# 2  StatusActive   0.00        Success        USA           False
# 3  StatusActive  65.00        Success        KAZ            True
# 4  StatusActive 145.00        Success        USA           False

# %%
df_USA_USSR = df_data[(df_data['Alpha3Code'] == "USA") | df_data['is_former_USSR']]

# %%
df_USA_USSR.head(1)
# Out:
#   Organisation                                    Location  \
# 0       SpaceX  LC-39A, Kennedy Space Center, Florida, USA
#
#                  Date                                        Detail  \
# 0 2020-08-07 05:12:00  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
#
#   Rocket_Status  Price Mission_Status Alpha3Code  is_former_USSR
# 0  StatusActive  50.00        Success        USA           False

# %%
pie_data = df_USA_USSR['is_former_USSR'].value_counts().reset_index(name='Count')

# %%
fig = px.pie(pie_data, values='Count', names='is_former_USSR', title='Former USSR vs US')

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="036059a2-9a6d-48dc-9a92-6348448aa358" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("036059a2-9a6d-48dc-9a92-6348448aa358")) {                    Plotly.newPlot(                        "036059a2-9a6d-48dc-9a92-6348448aa358",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"is_former_USSR=%{label}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":[true,false],"legendgroup":"","name":"","showlegend":true,"values":{"dtype":"i2","bdata":"MAhEBQ=="},"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidt ...

# %% [markdown]
# ## Create a Chart that Shows the Total Number of Launches Year-On-Year by the Two Superpowers

# %%
df_USA_USSR.shape
# Out:
# (3444, 9)

# %%
df_USA_USSR['Date'] = pd.to_datetime(df_USA_USSR['Date'], utc=True, errors='coerce').dt.tz_localize(None)
# Out:
# /tmp/ipython-input-4125528881.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_USA_USSR['Year'] = df_USA_USSR['Date'].dt.year
# Out:
# /tmp/ipython-input-647288207.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
launches_by_country = df_USA_USSR.groupby(['Year', 'is_former_USSR']).size().reset_index(name='Launches')

# %%
launches_by_country.head()
# Out:
#       Year  is_former_USSR  Launches
# 0 1,957.00           False         1
# 1 1,957.00            True         2
# 2 1,958.00           False        17
# 3 1,958.00            True         5
# 4 1,959.00           False        16

# %%
launches_by_country['Country_Group'] = launches_by_country['is_former_USSR'].map({
    True: 'Former USSR',
    False: 'USA'
})

fig = px.line(launches_by_country, x='Year', y='Launches', color='Country_Group')


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="9272e421-93de-4337-93e5-a8b1f2b1444a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9272e421-93de-4337-93e5-a8b1f2b1444a")) {                    Plotly.newPlot(                        "9272e421-93de-4337-93e5-a8b1f2b1444a",                        [{"hovertemplate":"Country_Group=USA\u003cbr\u003eYear=%{x}\u003cbr\u003eLaunches=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"USA","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"USA","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"\..."},"xaxis":"x","y":{"dtype":"i1","bdata":"AREQHis7DxchLxkWEQsQERAKDwsOFAkKDQoNEQ8GBgcQGhIbGBoeISQkHxwWERcQDBITDxkPEg0TFxMZHSIbFQ=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country_Group=Former USSR\u003cbr\u003eYear=%{x}\u003cbr\u003eLaunches=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Former USSR","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Former USSR","orientation":"v","showlegend":true,"x":{"dtype":"f8","bdata":"\..."},"xaxis":"x","y":{"dtype":"i1","bdata":"AgUECAkWFyE0MkpNU1daTFFSWF1cRCEmLjUsKDEwKCIYIhsXGxMOCgoKBQkHCAkIBwcICAkKBgEKBwURExEWCQ=="},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#4 ...

# %% [markdown]
# ## Chart the Total Number of Mission Failures Year on Year.

# %%
df_data['Date'] = pd.to_datetime(df_data['Date'], utc=True, errors='coerce').dt.tz_localize(None)

# %%
df_data['Year'] = df_data['Date'].dt.year

# %%
failed_missions = df_data[df_data['Mission_Status'] == 'Failure']

# %%
failed_missions_by_year = failed_missions.groupby('Year').size().reset_index(name='Count')

# %%
fig = px.line(failed_missions_by_year, x='Year', y='Count')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="5128347b-781d-46b2-9d83-c6972675690f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5128347b-781d-46b2-9d83-c6972675690f")) {                    Plotly.newPlot(                        "5128347b-781d-46b2-9d83-c6972675690f",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"\"},"xaxis":"x","y":{"dtype":"i1","bdata":"AQ4JExEOCQcKBwgEDwoMBwUHBgMEAQIDAgMBAQUEAgEBAwMDBAQFAwIEBgQBAQIDAwIBAwMBAQIBAQIFAgUG"},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords ...

# %% [markdown]
# ## Chart the Percentage of Failures over Time
#
# Did failures go up or down over time? Did the countries get better at minimising risk and improving their chances of success over time?

# %%
failed_missions = df_data[df_data['Mission_Status'] == 'Failure']

# %%
failed_missions_by_year = failed_missions.groupby('Year').size().reset_index(name='Count')

# %%
failed_missions_by_year.head()
# Out:
#       Year  Count
# 0 1,957.00      1
# 1 1,958.00     14
# 2 1,959.00      9
# 3 1,960.00     19
# 4 1,961.00     17

# %%
total_mission_by_year = df_data.groupby('Year').size().reset_index(name='Count')

# %%
total_mission_by_year.head()
# Out:
#       Year  Count
# 0 1,957.00      3
# 1 1,958.00     22
# 2 1,959.00     20
# 3 1,960.00     38
# 4 1,961.00     52

# %%
df_failed_total = failed_missions_by_year.merge(
    total_mission_by_year,
    on='Year',
    suffixes=('_failed', '_total')
)

# %%
df_failed_total.head()
# Out:
#       Year  Count_failed  Count_total
# 0 1,957.00             1            3
# 1 1,958.00            14           22
# 2 1,959.00             9           20
# 3 1,960.00            19           38
# 4 1,961.00            17           52

# %%
df_failed_total['Failed_percentage'] = df_failed_total['Count_failed'] / df_failed_total['Count_total']

# %%
df_failed_total.head()
# Out:
#       Year  Count_failed  Count_total  Failed_percentage
# 0 1,957.00             1            3               0.33
# 1 1,958.00            14           22               0.64
# 2 1,959.00             9           20               0.45
# 3 1,960.00            19           38               0.50
# 4 1,961.00            17           52               0.33

# %%
fig = px.line(df_failed_total, x='Year', y='Failed_percentage', title='Failed Mission Pct by Year')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="d924157f-741a-4f43-84ed-3c4db671c506" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d924157f-741a-4f43-84ed-3c4db671c506")) {                    Plotly.newPlot(                        "d924157f-741a-4f43-84ed-3c4db671c506",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eFailed_percentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":{"dtype":"f8","bdata":"\"},"xaxis":"x","y":{"dtype":"f8","bdata":"VVVVVVVV1T9ddNFFF13kP83MzMzMzNw\u002fAAAAAAAA4D\u002fFTuzETuzUP6QMPN2aH8Y\u002fDeU1lNdQzj8AAAAAAADAP3FH3BF3xL0\u002fkiRJkiRJsj8UFBQUFBS0P3sUrkfheqQ\u002fW6wM34gCwz\u002fyVvY5pCa4P2G5pxGWe7o\u002fq6qqqqqqsj8xb2dIzNupPxKZhu1mebI\u002f27Zt27Ztqz\u002fwwkH0+C6cP6AsgU37yaI\u002fBhZYYIEFhj9kIQtZyEKmP57YiZ3Yia0\u002fCB988MEHnz9GF1100UWnPwAAAAAAAJA\u002fZ7fwqzGRjj\u002fnQKIVNgeyPzvavE9xybA\u002faC+hvYT2oj+SJEmSJEmSP3sUrkfhepQ\u002fXkN5DeU1pD8or6G8hvKqP8YYY4wxxqg\u002fO9q8T3HJsD+EEEIIIYSwP1VVVVVVVbU\u002fmpmZmZmZqT\u002fbgbl2YK6dP2e38Ksxka4\u002fIjXBeCv7vD9wH8F9BPexPxiGYRiGYZg\u002fZCELWchClj85BS+n4OWkPxxMkc+6wbQ\u002f1ofG+tBYrz85BS+n4OWkP1cQkyuIyZU\u002f1ofG+tBYrz9VVVVVVVW1P\u002foYnI\u002fB+Zg\u002fHh4eHh4enj9kIQtZyEKmPxQ7sRM7sZM\u002fZCELWchClj9GF1100UWXPxzHcRzHcaw\u002fEhiBERiBkT\u002fv1LUc3OynPxiGYRiGYbg\u002f"},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333," ...

# %% [markdown]
# # For Every Year Show which Country was in the Lead in terms of Total Number of Launches up to and including including 2020)
#
# Do the results change if we only look at the number of successful launches?

# %%
success_missions = df_data[df_data['Mission_Status'] == 'Success']

# %%
success_missions.head(1)
# Out:
#   Organisation                                    Location  \
# 0       SpaceX  LC-39A, Kennedy Space Center, Florida, USA
#
#                  Date                                        Detail  \
# 0 2020-08-07 05:12:00  Falcon 9 Block 5 | Starlink V1 L9 & BlackSky
#
#   Rocket_Status  Price Mission_Status Alpha3Code  is_former_USSR     Year
# 0  StatusActive  50.00        Success        USA           False 2,020.00

# %%
lead_countries = success_missions.groupby(['Year', 'Alpha3Code'], as_index=False).size()

# %%
lead_countries_by_year = lead_countries.sort_values(by='size', ascending=False).drop_duplicates('Year')

# %%
lead_countries_by_year.head()
# Out:
#        Year Alpha3Code  size
# 82 1,977.00        RUS    67
# 72 1,975.00        RUS    64
# 60 1,973.00        RUS    63
# 77 1,976.00        RUS    62
# 87 1,978.00        RUS    58

# %%
## method 2

lead_countries = success_missions.groupby(['Year', 'Alpha3Code'], as_index=False).size()
idx = lead_countries.groupby('Year')['size'].idxmax()
top_country_per_year = lead_countries.loc[idx]

# %%
top_country_per_year.head()
# Out:
#       Year Alpha3Code  size
# 0 1,957.00        KAZ     2
# 2 1,958.00        USA     5
# 4 1,959.00        USA     6
# 6 1,960.00        USA    16
# 8 1,961.00        USA    27

# %%
fig = px.bar(top_country_per_year, x='Year', y='size', color='Alpha3Code')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="7c8fd6dd-1d34-4574-9af7-30a602bc7a55" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7c8fd6dd-1d34-4574-9af7-30a602bc7a55")) {                    Plotly.newPlot(                        "7c8fd6dd-1d34-4574-9af7-30a602bc7a55",                        [{"hovertemplate":"Alpha3Code=KAZ\u003cbr\u003eYear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"KAZ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"KAZ","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAACUnkAAAAAAALCeQAAAAAAAtJ5A"},"xaxis":"x","y":{"dtype":"i1","bdata":"AhUo"},"yaxis":"y","type":"bar"},{"hovertemplate":"Alpha3Code=USA\u003cbr\u003eYear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"USA","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"USA","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":""},"xaxis":"x","y":{"dtype":"i1","bdata":"BQYQGzINKBoYGiAjIhscFREWDwwREQ4YDxEMExYSGB0U"},"yaxis":"y","type":"bar"},{"hovertemplate":"Alpha3Code=RUS\u003cbr\u003eYear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RUS","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"RUS","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":""},"xaxis":"x","y":{"dtype":"i1","bdata":"ISUoMzM0PzhAPkM6Hh4hKCYjJSYbGRMbFxU="},"yaxis":"y","type":"bar"},{"hovertemplate":"Alpha3Code=CHN\u003cbr\u003eYear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CHN","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"CHN","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAACIn0AAAAAAAIyfQA=="},"xaxis":"x","y":{"dtype":"i1","bdata":"Jh8="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666 ...

# %% [markdown]
# # Create a Year-on-Year Chart Showing the Organisation Doing the Most Number of Launches
#
# Which organisation was dominant in the 1970s and 1980s? Which organisation was dominant in 2018, 2019 and 2020?

# %%
orgs_by_year = df_data.groupby(['Year', 'Organisation'], as_index=False).size()

# %%
orgs_by_year.head()
# Out:
#       Year Organisation  size
# 0 1,957.00    RVSN USSR     2
# 1 1,957.00      US Navy     1
# 2 1,958.00         AMBA     7
# 3 1,958.00         NASA     2
# 4 1,958.00    RVSN USSR     5

# %%
idx = orgs_by_year.groupby('Year')['size'].idxmax()

# %%
most_launch_orgs_by_year = orgs_by_year.loc[idx]

# %%
most_launch_orgs_by_year.head()
# Out:
#        Year  Organisation  size
# 0  1,957.00     RVSN USSR     2
# 2  1,958.00          AMBA     7
# 10 1,959.00  US Air Force    10
# 15 1,960.00  US Air Force    21
# 19 1,961.00  US Air Force    23

# %%
fig = px.bar(most_launch_orgs_by_year, x='Year', y='size', color='Organisation')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="ee4a0c79-39ca-48df-b8c0-3d00243300c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ee4a0c79-39ca-48df-b8c0-3d00243300c0")) {                    Plotly.newPlot(                        "ee4a0c79-39ca-48df-b8c0-3d00243300c0",                        [{"hovertemplate":"Organisation=RVSN USSR\u003cbr\u003eYear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"RVSN USSR","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"RVSN USSR","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":""},"xaxis":"x","y":{"dtype":"i1","bdata":"AhchNDJJTVJWWkxRUlhdXEQhJi41LCgxMCgiGCIa"},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=AMBA\u003cbr\u003eYear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AMBA","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"AMBA","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAACYnkA="},"xaxis":"x","y":{"dtype":"i1","bdata":"Bw=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=US Air Force\u003cbr\u003eYear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"US Air Force","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"US Air Force","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAACcnkAAAAAAAKCeQAAAAAAApJ5AAAAAAAConkA="},"xaxis":"x","y":{"dtype":"i1","bdata":"ChUXKA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=VKS RF\u003cbr\u003eYear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"VKS RF","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"VKS RF","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAgn0AAAAAAACSfQAAAAAAAKJ9A"},"xaxis":"x","y":{"dtype":"i1","bdata":"DhoT"},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=Lockheed\u003cbr\u003eYear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lockheed","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Lockheed","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAsn0A="},"xaxis":"x","y":{"dtype":"i1","bdata":"DA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=Arianespace\u003cbr\u003eYear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Arianespace","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Arianespace","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAAwn0AAAAAAADSfQAAAAAAAQJ9AAAAAAABEn0AAAAAAAEifQAAAAAAAVJ9AAAAAAAB8n0A="},"xaxis":"x","y":{"dtype":"i1","bdata":"CgsMCAwFDA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=Boeing\u003cbr\u003eYear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Boeing","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Boeing","orientation":"v","showlegend":true,"textposition":"auto","x":{"dtype":"f8","bdata":"AAAAAAA4n0AAAAAAADyfQAAAAAAATJ9AAAAAAABQn0AAAAAAAFifQA=="},"xaxis":"x","y":{"dtype":"i1","bdata":"DQsJCAg="},"yaxis":"y","type":"bar"},{"hovertemplate":"Organisation=ULA\u003cbr\u003eYear=%{x}\u003cbr\u003esize=%{y}\u003cextra\u00 ...
